# %% [markdown]
# <font size="+5">#03. Machine Learning & Linear Regression</font>

# %% [markdown]
# - Book + Private Lessons [Here ↗](https://sotastica.com/reservar)
# - Subscribe to my [Blog ↗](https://blog.pythonassembly.com/)
# - Let's keep in touch on [LinkedIn ↗](www.linkedin.com/in/jsulopz) 😄

# %% [markdown]
# # Discipline to Search Solutions in Google

# %% [markdown]
# > Apply the following steps when **looking for solutions in Google**:
# >
# > 1. **Necesity**: How to load an Excel in Python?
# > 2. **Search in Google**: by keywords
# >   - `load excel python`
# >   - ~~how to load excel in python~~
# > 3. **Solution**: What's the `function()` that loads an Excel in Python?
# >   - A Function to Programming is what the Atom to Phisics.
# >   - Every time you want to do something in programming
# >   - **You will need a `function()`** to make it
# >   - Theferore, you must **detect parenthesis `()`**
# >   - Out of all the words that you see in a website
# >   - Because they indicate the presence of a `function()`.

# %% [markdown]
# # Load the Data

# %% [markdown]
# > - Simply execute the following lines of code to load the data.
# > - This dataset contains **statistics about Car Accidents** (columns)
# > - In each one of **USA States** (rows)

# %% [markdown]
# https://www.kaggle.com/fivethirtyeight/fivethirtyeight-bad-drivers-dataset/

# %%
import seaborn as sns

df = sns.load_dataset(name='car_crashes', index_col='abbrev')
df
# Out:
#         total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# abbrev
# AL       18.8     7.332    5.640          18.048       15.040       784.55
# AK       18.1     7.421    4.525          16.290       17.014      1053.48
# AZ       18.6     6.510    5.208          15.624       17.856       899.47
# AR       22.4     4.032    5.824          21.056       21.280       827.34
# CA       12.0     4.200    3.360          10.920       10.680       878.41
# CO       13.6     5.032    3.808          10.744       12.920       835.50
# CT       10.8     4.968    3.888           9.396        8.856      1068.73
# DE       16.2     6.156    4.860          14.094       16.038      1137.87
# DC        5.9     2.006    1.593           5.900        5.900      1273.89
# FL       17.9     3.759    5.191          16.468       16.826      1160.13
# GA       15.6     2.964    3.900          14.820       14.508       913.15
# HI       17.5     9.450    7.175          14.350       15.225       861.18
# ID       15.3     5.508    4.437          13.005       14.994       641.96
# IL       12.8     4.608    4.352          12.032       12.288       803.11
# IN       14.5     3.625    4.205          13.775       13.775       710.46
# IA       15.7     2.669    3.925          15.229       13.659       649.06
# KS       17.8     4.806    4.272          13.706       15.130       780.45
# KY       21.4     4.066    4.922          16.692       16.264       872.51
# LA       20.5     7.175    6.765          14.965       20.090      1281.55
# ME       15.1     5.738    4.530          13.137       12.684       661.88
# MD       12.5     4.250    4.000           8.875       12.375      1048.78
# MA        8.2     1.886    2.870           7.134        6.560      1011.14
# MI       14.1     3.384    3.948          13.395       10.857      1110.61
# MN        9.6     2.208    2.784           8.448        8.448       777.18
# MS       17.6     2.640    5.456           1.760       17.600       896.07
# MO       16.1     6.923    5.474          14.812       13.524       790.32
# MT       21.4     8.346    9.416          17.976       18.190       816.21
# NE       14.9     1.937    5.215          13.857       13.410       732.28
# NV       14.7     5.439    4.704          13.965       14.553      1029.87
# NH       11.6     4.060    3.480          10.092        9.628       746.54
# NJ       11.2     1.792    3.136           9.632        8.736      1301.52
# NM       18.4     3.496    4.968          12.328       18.032       869.85
# NY       12.3     3.936    3.567          10.824        9.840      1234.31
# NC       16.8     6.552    5.208          15.792       13.608       708.24
# ND       23.9     5.497   10.038          23.661       20.554       688.75
# OH       14.1     3.948    4.794          13.959       11.562       697.73
# OK       19.9     6.368    5.771          18.308       18.706       881.51
# OR       12.8     4.224    3.328           8.576       11.520       804.71
# PA       18.2     9.100    5.642          17.472       16.016       905.99
# RI       11.1     3.774    4.218          10.212        8.769      1148.99
# SC       23.9     9.082    9.799          22.944       19.359       858.97
# SD       19.4     6.014    6.402          19.012       16.684       669.31
# TN       19.5     4.095    5.655          15.990       15.795       767.91
# TX       19.4     7.760    7.372          17.654       16.878      1004.75
# UT       11.3     4.859    1.808           9.944       10.848       809.38
# VT       13.6     4.080    4.080          13.056       12.920       716.20
# VA       12.7     2.413    3.429          11.049       11.176       768.95
# WA       10.6     4.452    3.498           8.692        9.116       890.03
# WV       23.8     8.092    6.664          23.086       20.706       992.61
# WI       13.8     4.968    4.554           5.382       11.592       670.31
# WY       17.4     7.308    5.568          14.094       15.660       791.14
#
#         ins_losses
# abbrev
# AL          145.08
# AK          133.93
# AZ          110.35
# AR          142.39
# CA          165.63
# CO          139.91
# CT          167.02
# DE          151.48
# DC          136.05
# FL          144.18
# GA          142.80
# HI          120.92
# ID           82.75
# IL          139.15
# IN          108.92
# IA          114.47
# KS          133.80
# KY          137.13
# LA          194.78
# ME           96.57
# MD          192.70
# MA          135.63
# MI          152.26
# MN          133.35
# MS          155.77
# MO          144.45
# MT           85.15
# NE          114.82
# NV          138.71
# NH          120.21
# NJ          159.85
# NM          120.75
# NY          150.01
# NC          127.82
# ND          109.72
# OH          133.52
# OK          178.86
# OR          104.61
# PA          153.86
# RI          148.58
# SC          116.29
# SD           96.87
# TN          155.57
# TX          156.83
# UT          109.48
# VT          109.61
# VA          153.72
# WA          111.62
# WV          152.56
# WI          106.62
# WY          122.04

# %% [markdown]
# # Data Visualization to Analyize Patterns

# %% [markdown]
# > Choose two variables that have a relationship. For example, would the `total` number of accidents **increase** if alcohol also increases?
# > As the 2 variables are **numerical**, visualize the data with a `scatterplot()`.
# >
# > - Is there a figure that can represents the relationship between these 2 variables? Which one?

# %%
sns.scatterplot(x = df.alcohol, y = df.total);

# %% [markdown]
# # Machine Learning, what does it mean?

# %% [markdown]
# > - The Machine Learns...
# >
# > But, **what does it learn?**

# %%
# %%HTML
# <blockquote class="twitter-tweet" data-lang="en"><p lang="en" dir="ltr">Machine Learning, what does it mean? ⏯<br><br>· The machine learns...<br><br>Ha ha, not funny! 🤨 What does it learn?<br><br>· A mathematical equation. For example: <a href="https://t.co/sjtq9F2pq7">pic.twitter.com/sjtq9F2pq7</a></p>&mdash; Jesús López (@sotastica) <a href="https://twitter.com/sotastica/status/1449735653328031745?ref_src=twsrc%5Etfw">October 17, 2021</a></blockquote> <script async src="https://platform.twitter.com/widgets.js" charset="utf-8"></script>
# Out:
# <blockquote class="twitter-tweet" data-lang="en"><p lang="en" dir="ltr">Machine Learning, what does it mean? ⏯<br><br>· The machine learns...<br><br>Ha ha, not funny! 🤨 What does it learn?<br><br>· A mathematical equation. For example: <a href="https://t.co/sjtq9F2pq7">pic.twitter.com/sjtq9F2pq7</a></p>&mdash; Jesús López (@sotastica) <a href="https://twitter.com/sotastica/status/1449735653328031745?ref_src=twsrc%5Etfw">October 17, 2021</a></blockquote> <script async src="https://platform.twitter.com/widgets.js" charset="utf-8"></script>

# %% [markdown]
# # How does the Machine Learn?

# %% [markdown]
# ## In a Linear Regression

# %%
# %%HTML
# <iframe width="560" height="315" src="https://www.youtube.com/embed/Ht3rYS-JilE" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/Ht3rYS-JilE" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# ## In a Neural Network

# %%
# %%HTML
# <iframe width="560" height="315" src="https://www.youtube.com/embed/IHZwWFHWa-w?start=36" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/IHZwWFHWa-w?start=36" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# A Practical Example → [Tesla Autopilot](https://www.tesla.com/AI)

# %% [markdown]
# An Example where It Fails → [Tesla Confuses Moon with Semaphore](https://twitter.com/Carnage4Life/status/1418920100086784000?s=20)

# %% [markdown]
# # `LinearRegression()` Model in Python

# %% [markdown]
# ## Build the Model

# %% [markdown]
# > 1. **Necesity**: Build Model
# > 2. **Google**: How do you search for the solution?
# > 3. **Solution**: Find the `function()` that makes it happen

# %% [markdown]
# ## Code Thinking
#
# > Which function computes the Model?
# > - `fit()`
# >
# > How could can you **import the function in Python**?

# %%
fit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/24/tg28vxls25l9mjvqrnh0plc80000gn/T/ipykernel_35323/3324602025.py in <module>
# ----> 1 fit()
#
# NameError: name 'fit' is not defined

# %%
algo.fit()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/24/tg28vxls25l9mjvqrnh0plc80000gn/T/ipykernel_35323/22777151.py in <module>
# ----> 1 algo.fit()
#
# TypeError: fit() missing 2 required positional arguments: 'X' and 'y'

# %% [markdown]
# `algo = ?`

# %%
algo = list()

# %%
algo
# Out:
# []

# %%
type(algo)
# Out:
# list

# %%
algo.
# Out:
#   File "/var/folders/24/tg28vxls25l9mjvqrnh0plc80000gn/T/ipykernel_35323/2794071594.py", line 1
#     algo.
#          ^
# SyntaxError: invalid syntax

# %%
algo = LinearRegression()

# %%
from sklearn.linear_model import LinearRegression

# %%
algo = LinearRegression()

# %%
algo.fit()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/24/tg28vxls25l9mjvqrnh0plc80000gn/T/ipykernel_35323/22777151.py in <module>
# ----> 1 algo.fit()
#
# TypeError: fit() missing 2 required positional arguments: 'X' and 'y'

# %% [markdown]
# ### Separate Variables for the Model
#
# > Regarding their role:
# > 1. **Target Variable `y`**
# >
# > - [ ] What would you like **to predict**?
# >
# > Total number of accients? Or Alcohol?
# >
# > 2. **Explanatory Variable `X`**
# >
# > - [ ] Which variable will you use **to explain** the target?

# %%
explanatory = df[['alcohol']]
target = df[['total']] #queremos ver como cambia el total (nuestro objetivo) sobre la explicación (el alcohol)

# %% [markdown]
# ### Finally `fit()` the Model

# %%
from sklearn.linear_model import LinearRegression

# %%
algo = LinearRegression()

# %%
algo.__dict__
# Out:
# {'fit_intercept': True,
#  'normalize': 'deprecated',
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False}

# %%
algo.predict(X=explanatory)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# /var/folders/24/tg28vxls25l9mjvqrnh0plc80000gn/T/ipykernel_35323/182535694.py in <module>
# ----> 1 algo.predict(X=explanatory)
#
# ~/miniforge3/lib/python3.9/site-packages/sklearn/linear_model/_base.py in predict(self, X)
#     360             Returns predicted values.
#     361         """
# --> 362         return self._decision_function(X)
#     363
#     364     _preprocess_data = staticmethod(_preprocess_data)
#
# ~/miniforge3/lib/python3.9/site-packages/sklearn/linear_model/_base.py in _decision_function(self, X)
#     341
#     342     def _decision_function(self, X):
# --> 343         check_is_fitted(self)
#     344
#     345         X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#
# ~/miniforge3/lib/python3.9/site-packages/sklearn/utils/validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1207
#    1208     if not fitted:
# -> 1209         raise NotFittedError(msg % {"name": type(estimator).__name__})
#    1210
#    1211
#
# NotFittedError: This LinearRegression instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.

# %%
algo.fit(X= explanatory, y = target)
# Out:
# LinearRegression()

# %% [markdown]
# ## Model's Mathematical Equation

# %% [markdown]
# > A model is nothing more than a mathematical equation that **helps you to calculate** something. For example:
# >
# > 1. **Churn**: which is the probability for this client not to buy me anymore?
# > 2. **Credit Approval**: which is the probability for this client to pay the credit?
# > 3. **Athlete's Injury**: which is the probability for this athlete to have an injury in the next game?
# > 4. **Car Rental**: how many cars will people rent tomorrow?
# >
# > For our case: **how many accidents** the State will have (based on alcohol)?
# > - Which is the mathematical equation?

# %%
algo.__dict__
# Out:
# {'fit_intercept': True,
#  'normalize': 'deprecated',
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['alcohol'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([[2.0325063]]),
#  '_residues': array([231.96888653]),
#  'rank_': 1,
#  'singular_': array([12.22681605]),
#  'intercept_': array([5.85777615])}

# %% [markdown]
# ## Model Interpretation

# %% [markdown]
# > - How many accidents will happen for every **one unit increase in alcohol**?

# %% [markdown]
# $$
# accidentes = a + b \cdot alcohol \\
# accidentes = 5.85 + 2.03 \cdot alcohol \\
# y = 5.85 + 2.03 \cdot x
# $$

# %% [markdown]
# ## External Code Execution

# %% [markdown]
# > - What have happened **inside the computer** to get the model equation?

# %% [markdown]
# ## Calculate a Prediction with the Model

# %% [markdown]
# > **Programming thiking:**
# >
# > - Which `function()` can we use to make a prediction?
# > - How can you answer yourself **without searching in Google**?

# %%
a = explanatory.sample()

# %%
a
# Out:
#         alcohol
# abbrev
# TX        7.372

# %%
algo.predict(a)
# Out:
# array([[20.84141263]])

# %%
pred = algo.predict(X=explanatory)

# %%
dfselect = df[['alcohol', 'total']]

# %%
dfselect['predicciones'] = pred
# Out:
# /var/folders/24/tg28vxls25l9mjvqrnh0plc80000gn/T/ipykernel_8190/1333751335.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfselect['predicciones'] = pred

# %% [markdown]
# ## Model Visualization

# %% [markdown]
# > 1. What would happend if you **plot the predictions**?
# > 2. And the **real data**?

# %%
sns.scatterplot(x = df.alcohol, y = df.total);
sns.scatterplot(x = df.alcohol, y = pred.flatten());

# %% [markdown]
# # How good is my model? **Goodness of Fit**

# %% [markdown]
# > - How can we compare **reality vs. predictions**?

# %%
algo.score(X=explanatory, y=target)
# Out:
# 0.7269492966665405

# %% [markdown]
# # Other Regression Models to Calculate Accidents

# %% [markdown]
# > Tutorial → [Why All Machine Learning Models Are the Same](https://blogsotastico.com/why-all-machine-learning-models-are-the-same)

# %% [markdown]
# ## `RandomForestRegression()`

# %%
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# El orden siempre igual:
#
# 1) fit para ENTRENAR
#
# 2) predict para hacer la PREDICCIÓN
#
# 3) score para sacar el PORCENTAJE de aproximación

# %%
rf = RandomForestRegressor()

# %%
rf.fit(X=explanatory, y=target)
# Out:
# /var/folders/24/tg28vxls25l9mjvqrnh0plc80000gn/T/ipykernel_8190/614680796.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X=explanatory, y=target)
# RandomForestRegressor()

# %%
dfselect['prediccion_rf'] = predicciones
# Out:
# /var/folders/24/tg28vxls25l9mjvqrnh0plc80000gn/T/ipykernel_8190/2635784151.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfselect['prediccion_rf'] = predicciones

# %%
dfselect
# Out:
#         alcohol  total  predicciones  prediccion_rf
# abbrev
# AL        5.640   18.8     17.321112       18.63000
# AK        4.525   18.1     15.054867       16.76300
# AZ        5.208   18.6     16.443069       17.41575
# AR        5.824   22.4     17.695093       21.31300
# CA        3.360   12.0     12.686997       12.18100
# CO        3.808   13.6     13.597560       13.35500
# CT        3.888   10.8     13.760161       12.73500
# DE        4.860   16.2     15.735757       18.04200
# DC        1.593    5.9      9.095559        7.52100
# FL        5.191   17.9     16.408516       17.75095
# GA        3.900   15.6     13.784551       14.22300
# HI        7.175   17.5     20.441009       18.28100
# ID        4.437   15.3     14.876007       14.97800
# IL        4.352   12.8     14.703244       14.34100
# IN        4.205   14.5     14.404465       13.95200
# IA        3.925   15.7     13.835363       15.23800
# KS        4.272   17.8     14.540643       16.25600
# KY        4.922   21.4     15.861772       20.14700
# LA        6.765   20.5     19.607681       20.97500
# ME        4.530   15.1     15.065030       15.65300
# MD        4.000   12.5     13.987801       13.34700
# MA        2.870    8.2     11.691069        8.89600
# MI        3.948   14.1     13.882111       14.53700
# MN        2.784    9.6     11.516274        9.58200
# MS        5.456   17.6     16.947131       17.29200
# MO        5.474   16.1     16.983716       16.69200
# MT        9.416   21.4     24.995856       22.11600
# NE        5.215   14.9     16.457297       16.01755
# NV        4.704   14.7     15.418686       14.51000
# NH        3.480   11.6     12.930898       11.47400
# NJ        3.136   11.2     12.231716       11.50000
# NM        4.968   18.4     15.955267       18.76900
# NY        3.567   12.3     13.107726       11.87900
# NC        5.208   16.8     16.443069       17.41575
# ND       10.038   23.9     26.260074       23.64100
# OH        4.794   14.1     15.601611       14.86900
# OK        5.771   19.9     17.587370       20.26300
# OR        3.328   12.8     12.621957       12.52500
# PA        5.642   18.2     17.325177       18.40800
# RI        4.218   11.1     14.430888       12.72000
# SC        9.799   23.9     25.774305       23.64100
# SD        6.402   19.4     18.869882       20.84800
# TN        5.655   19.5     17.351599       19.02700
# TX        7.372   19.4     20.841413       19.04100
# UT        1.808   11.3      9.532548        9.57300
# VT        4.080   13.6     14.150402       13.48600
# VA        3.429   12.7     12.827240       12.24800
# WA        3.498   10.6     12.967483       11.10400
# WV        6.664   23.8     19.402398       22.32800
# WI        4.554   13.8     15.113810       14.45300
# WY        5.568   17.4     17.174771       17.78200

# %%
rf.score(explanatory, target) # un 95% de que sea bueno
# Out:
# 0.9547829451683483

# %% [markdown]
# ## `SVR()`

# %% [markdown]
# # Visualize & Choose the Best Model

# %% [markdown]
# > - Which model is the best?
# > - Is there any **metric to compare** these models?
# > - Which is the metric?
# > - Get the metric for each model

# %%
from sklearn.svm import SVR

# %%
sv = SVR()

# %%
sv.fit(explanatory, target)
# Out:
# /Users/sota/miniforge3/lib/python3.9/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR()

# %%
prediccionsv = sv.predict(explanatory)

# %%
dfselect['prediccion_sv'] = prediccionsv
# Out:
# /var/folders/24/tg28vxls25l9mjvqrnh0plc80000gn/T/ipykernel_8190/2036735848.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfselect['prediccion_sv'] = prediccionsv

# %%
dfselect
# Out:
#         alcohol  total  predicciones  prediccion_rf  prediccion_sv
# abbrev
# AL        5.640   18.8     17.321112       18.63000      18.295708
# AK        4.525   18.1     15.054867       16.76300      15.184627
# AZ        5.208   18.6     16.443069       17.41575      17.222419
# AR        5.824   22.4     17.695093       21.31300      18.663318
# CA        3.360   12.0     12.686997       12.18100      12.124348
# CO        3.808   13.6     13.597560       13.35500      13.106916
# CT        3.888   10.8     13.760161       12.73500      13.316127
# DE        4.860   16.2     15.735757       18.04200      16.211312
# DC        1.593    5.9      9.095559        7.52100      12.660625
# FL        5.191   17.9     16.408516       17.75095      17.175372
# GA        3.900   15.6     13.784551       14.22300      13.348209
# HI        7.175   17.5     20.441009       18.28100      19.389203
# ID        4.437   15.3     14.876007       14.97800      14.914152
# IL        4.352   12.8     14.703244       14.34100      14.654670
# IN        4.205   14.5     14.404465       13.95200      14.213150
# IA        3.925   15.7     13.835363       15.23800      13.415602
# KS        4.272   17.8     14.540643       16.25600      14.412994
# KY        4.922   21.4     15.861772       20.14700      16.397525
# LA        6.765   20.5     19.607681       20.97500      19.489666
# ME        4.530   15.1     15.065030       15.65300      15.200028
# MD        4.000   12.5     13.987801       13.34700      13.622008
# MA        2.870    8.2     11.691069        8.89600      11.539048
# MI        3.948   14.1     13.882111       14.53700      13.478243
# MN        2.784    9.6     11.516274        9.58200      11.498189
# MS        5.456   17.6     16.947131       17.29200      17.870536
# MO        5.474   16.1     16.983716       16.69200      17.914427
# MT        9.416   21.4     24.995856       22.11600      19.607361
# NE        5.215   14.9     16.457297       16.01755      17.241704
# NV        4.704   14.7     15.418686       14.51000      15.735855
# NH        3.480   11.6     12.930898       11.47400      12.351366
# NJ        3.136   11.2     12.231716       11.50000      11.784815
# NM        4.968   18.4     15.955267       18.76900      16.534311
# NY        3.567   12.3     13.107726       11.87900      12.533732
# NC        5.208   16.8     16.443069       17.41575      17.222419
# ND       10.038   23.9     26.260074       23.64100      19.477393
# OH        4.794   14.1     15.601611       14.86900      16.011157
# OK        5.771   19.9     17.587370       20.26300      18.563797
# OR        3.328   12.8     12.621957       12.52500      12.068913
# PA        5.642   18.2     17.325177       18.40800      18.300028
# RI        4.218   11.1     14.430888       12.72000      14.251716
# SC        9.799   23.9     25.774305       23.64100      19.595977
# SD        6.402   19.4     18.869882       20.84800      19.379505
# TN        5.655   19.5     17.351599       19.02700      18.327942
# TX        7.372   19.4     20.841413       19.04100      19.299944
# UT        1.808   11.3      9.532548        9.57300      12.263457
# VT        4.080   13.6     14.150402       13.48600      13.848475
# VA        3.429   12.7     12.827240       12.24800      12.251280
# WA        3.498   10.6     12.967483       11.10400      12.387917
# WV        6.664   23.8     19.402398       22.32800      19.482122
# WI        4.554   13.8     15.113810       14.45300      15.273977
# WY        5.568   17.4     17.174771       17.78200      18.135725

# %%
sv.score(explanatory, target) # Un 70% se acerca, es el peor modelo
# Out:
# 0.7083438012012769

# %% [markdown]
# # PARA REPRESENTAR LOS MODELOS GRÁFICAMENTE

# %%
dfselect
# Out:
#         alcohol  total  predicciones  prediccion_rf  prediccion_sv
# abbrev
# AL        5.640   18.8     17.321112       18.63000      18.295708
# AK        4.525   18.1     15.054867       16.76300      15.184627
# AZ        5.208   18.6     16.443069       17.41575      17.222419
# AR        5.824   22.4     17.695093       21.31300      18.663318
# CA        3.360   12.0     12.686997       12.18100      12.124348
# CO        3.808   13.6     13.597560       13.35500      13.106916
# CT        3.888   10.8     13.760161       12.73500      13.316127
# DE        4.860   16.2     15.735757       18.04200      16.211312
# DC        1.593    5.9      9.095559        7.52100      12.660625
# FL        5.191   17.9     16.408516       17.75095      17.175372
# GA        3.900   15.6     13.784551       14.22300      13.348209
# HI        7.175   17.5     20.441009       18.28100      19.389203
# ID        4.437   15.3     14.876007       14.97800      14.914152
# IL        4.352   12.8     14.703244       14.34100      14.654670
# IN        4.205   14.5     14.404465       13.95200      14.213150
# IA        3.925   15.7     13.835363       15.23800      13.415602
# KS        4.272   17.8     14.540643       16.25600      14.412994
# KY        4.922   21.4     15.861772       20.14700      16.397525
# LA        6.765   20.5     19.607681       20.97500      19.489666
# ME        4.530   15.1     15.065030       15.65300      15.200028
# MD        4.000   12.5     13.987801       13.34700      13.622008
# MA        2.870    8.2     11.691069        8.89600      11.539048
# MI        3.948   14.1     13.882111       14.53700      13.478243
# MN        2.784    9.6     11.516274        9.58200      11.498189
# MS        5.456   17.6     16.947131       17.29200      17.870536
# MO        5.474   16.1     16.983716       16.69200      17.914427
# MT        9.416   21.4     24.995856       22.11600      19.607361
# NE        5.215   14.9     16.457297       16.01755      17.241704
# NV        4.704   14.7     15.418686       14.51000      15.735855
# NH        3.480   11.6     12.930898       11.47400      12.351366
# NJ        3.136   11.2     12.231716       11.50000      11.784815
# NM        4.968   18.4     15.955267       18.76900      16.534311
# NY        3.567   12.3     13.107726       11.87900      12.533732
# NC        5.208   16.8     16.443069       17.41575      17.222419
# ND       10.038   23.9     26.260074       23.64100      19.477393
# OH        4.794   14.1     15.601611       14.86900      16.011157
# OK        5.771   19.9     17.587370       20.26300      18.563797
# OR        3.328   12.8     12.621957       12.52500      12.068913
# PA        5.642   18.2     17.325177       18.40800      18.300028
# RI        4.218   11.1     14.430888       12.72000      14.251716
# SC        9.799   23.9     25.774305       23.64100      19.595977
# SD        6.402   19.4     18.869882       20.84800      19.379505
# TN        5.655   19.5     17.351599       19.02700      18.327942
# TX        7.372   19.4     20.841413       19.04100      19.299944
# UT        1.808   11.3      9.532548        9.57300      12.263457
# VT        4.080   13.6     14.150402       13.48600      13.848475
# VA        3.429   12.7     12.827240       12.24800      12.251280
# WA        3.498   10.6     12.967483       11.10400      12.387917
# WV        6.664   23.8     19.402398       22.32800      19.482122
# WI        4.554   13.8     15.113810       14.45300      15.273977
# WY        5.568   17.4     17.174771       17.78200      18.135725

# %%
sns.scatterplot(x= 'alcohol', y = 'total', data = dfselect)
sns.lineplot(x ='alcohol', y='predicciones', data=dfselect, color='red') #LR
sns.scatterplot(x='alcohol', y='prediccion_rf', data=dfselect, label='rf') #RF
sns.scatterplot(x='alcohol', y='prediccion_sv', data=dfselect) #SV
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='total'>
